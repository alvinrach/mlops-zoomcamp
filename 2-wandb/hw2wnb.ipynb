# %% [markdown]
# # What is the version of wandb?

# %%
# !wandb --version
# Out:
# wandb, version 0.15.4

# %%
# !wget -P ./data/ https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-01.parquet
# !wget -P ./data/ https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-02.parquet
# !wget -P ./data/ https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-03.parquet
# Out:
# --2023-06-19 08:06:53--  https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-01.parquet
# Resolving d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 108.138.187.136, 108.138.187.137, 108.138.187.25, ...
# Connecting to d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|108.138.187.136|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1254291 (1.2M) [binary/octet-stream]
# Saving to: ‘./data/green_tripdata_2022-01.parquet.1’
#
# green_tripdata_2022 100%[===================>]   1.20M  1.54MB/s    in 0.8s
#
# 2023-06-19 08:06:54 (1.54 MB/s) - ‘./data/green_tripdata_2022-01.parquet.1’ saved [1254291/1254291]
#
# --2023-06-19 08:06:55--  https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2022-02.parquet
# Resolving d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 108.138.187.208, 108.138.187.136, 108.138.187.137, ...
# ...

# %% [markdown]
# # What is the size of dv.pkl?

# %%
# Must in terminal
! python preprocess_data.py \
  --wandb_project project-zoomcamp \
  --wandb_entity alvinrach \
  --raw_data_path ./data/ \
  --dest_path ./output
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: ^C
#
# Aborted!

# %%
# !cd ./output/ && du -sh *
# Out:
# 152K	dv.pkl
# 2.6M	test.pkl
# 2.1M	train.pkl
# 2.3M	val.pkl

# %% [markdown]
# # The value of maximum depth parameter

# %%
# !python train.py \
  --wandb_project project-zoomcamp \
  --wandb_entity alvinrach \
  --data_artifact "alvinrach/project-zoomcamp/NYC-Taxi:v0"
# Out:
# wandb: Currently logged in as: alvinrach. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /workspaces/mlops-zoomcamp/2-wandb/wandb/run-20230619_085004-gt8pwi70
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run scarlet-bee-2
# wandb: ⭐️ View project at https://wandb.ai/alvinrach/project-zoomcamp
# wandb: 🚀 View run at https://wandb.ai/alvinrach/project-zoomcamp/runs/gt8pwi70
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb: 🚀 View run scarlet-bee-2 at: https://wandb.ai/alvinrach/project-zoomcamp/runs/gt8pwi70
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230619_085004-gt8pwi70/logs

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Most Important Hyperparameter (Not Variable/Feature)

# %%
# !python sweep.py \
  --wandb_project project-zoomcamp \
  --wandb_entity alvinrach \
  --data_artifact "alvinrach/project-zoomcamp/NYC-Taxi:v0"
# Out:
# Create sweep with ID: llsllfvi
# Sweep URL: https://wandb.ai/alvinrach/project-zoomcamp/sweeps/llsllfvi
# wandb: Agent Starting Run: ubrvg1fx with config:
# wandb: 	max_depth: 10
# wandb: 	min_samples_leaf: 2
# wandb: 	min_samples_split: 2
# wandb: 	n_estimators: 36
# wandb: Currently logged in as: alvinrach. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /workspaces/mlops-zoomcamp/2-wandb/wandb/run-20230619_090209-ubrvg1fx
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run restful-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/alvinrach/project-zoomcamp
# wandb: 🧹 View sweep at https://wandb.ai/alvinrach/project-zoomcamp/sweeps/llsllfvi
# wandb: 🚀 View run at https://wandb.ai/alvinrach/project-zoomcamp/runs/ubrvg1fx
# wandb:   4 of 4 files downloaded.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb: MSE ▁
# wandb:
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Registered Model UI

# %% [markdown]
# ![image.png](attachment:image.png)
